# %%
! pip install langchain langchain-community langchain-google-genai chromadb pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.4/331.4 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 59.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 40.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 3.3 MB/s eta 0:00:00
# ...

# %%
! pip install openai langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.8 MB/s eta 0:00:00
# ...

# %%
! pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# accelerate                               1.12.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.3
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.4
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# ...

# %%
! python -m pip install --u pgrade pip
# Out:
# Usage:
#   /usr/bin/python3 -m pip install [options] <requirement specifier> [package-index-options] ...
#   /usr/bin/python3 -m pip install [options] -r <requirements file> [package-index-options] ...
#   /usr/bin/python3 -m pip install [options] [-e] <vcs project url> ...
#   /usr/bin/python3 -m pip install [options] [-e] <local project path> ...
#   /usr/bin/python3 -m pip install [options] <archive url/path> ...
#
# ambiguous option: --u (--upgrade, --upgrade-strategy, --use-deprecated, --use-feature, --use-pep517, --user?)

# %%
! pip install --upgrade langchain langchain-community

# %%
! pip install langchain langchain-community langchain-google-genai chromadb pypdf

# %%
! pip install langchain-text-splitters

# %%
! pip uninstall google-generativeai langchain-google-genai -y
! pip install -U google-generativeai langchain-google-genai
# Out:
# Found existing installation: google-generativeai 0.8.6
# Uninstalling google-generativeai-0.8.6:
#   Successfully uninstalled google-generativeai-0.8.6
# Found existing installation: langchain-google-genai 4.2.1
# Uninstalling langchain-google-genai-4.2.1:
#   Successfully uninstalled langchain-google-genai-4.2.1
# ...
#   Using cached langchain_google_genai-4.2.1-py3-none-any.whl.metadata (2.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.1/155.1 kB 6.9 MB/s eta 0:00:00
# Using cached langchain_google_genai-4.2.1-py3-none-any.whl (66 kB)
# ...

# %%
! pip show langchain-google-genai
! pip show google-genai
# Out:
# Name: langchain-google-genai
# Version: 4.2.1
# Summary: An integration package connecting Google's genai package and LangChain
# Home-page: https://docs.langchain.com/oss/python/integrations/providers/google
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: filetype, google-genai, langchain-core, pydantic
# Required-by:
# Name: google-genai
# Version: 1.65.0
# Summary: GenAI Python SDK
# Home-page: https://github.com/googleapis/python-genai
# Author:
# Author-email: Google LLC <googleapis-packages@google.com>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: anyio, distro, google-auth, httpx, pydantic, requests, sniffio, tenacity, typing-extensions, websockets
# Required-by: google-adk, google-cloud-aiplatform, langchain-google-genai

# %%
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyC1iFvXSokTN1jXIatSOiRQkEoGWlC_KIM"

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings

from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import Chroma

from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
# Load
from google.colab import files
uploaded = files.upload()
loader = PyPDFLoader("PowerBI.pdf")
documents = loader.load()
# Out:
#      <input type="file" id="files-cd4f4f06-7538-4fb1-9c8e-710cbe9ba25a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd4f4f06-7538-4fb1-9c8e-710cbe9ba25a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Split
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

docs = text_splitter.split_documents(documents)

# %%
# embeddings
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Vector Store
vectorstore = Chroma.from_documents(docs, embeddings)
retriever = vectorstore.as_retriever()

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# %%
# Prompt
prompt = ChatPromptTemplate.from_template("""
Answer the question based only on the context below.

Context:
{context}

Question:
{question}
""")

# %%
# RAG Chain (Modern LCEL)
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
# Ask Question
response = rag_chain.invoke(
    "What are the key features for this project?"
)
print(response)
# Out:
# The key features for this project (referring to Power BI) are:
# *   **Data Analysis:** Power BI can perform data analysis from various sources like spreadsheets, databases, and cloud services, enabling users to create reports and dashboards for insights into business metrics and trends.
# *   **Data Visualization:** It offers a wide range of tools for creating engaging and interactive reports and dashboards, with options for charts, graphs, maps, and other visualizations.
# *   **Collaboration:** Power BI allows users to share and collaborate on reports and dashboards with colleagues and stakeholders in real-time.
# *   **Mobile Access:** It is supported on mobile devices, providing access to reports and dashboards from anywhere, at any time.

# %%
response = rag_chain.invoke(
    "What makes your dashboard different from traditional reports?"
)
print(response)
# Out:
# Based on the provided context, there is no information describing what makes "your dashboard" different from traditional reports. The context only details steps for enhancing a dashboard's visual appeal and lists various dashboards.

# %%
response = rag_chain.invoke(
    "How it works?"
)
print(response)
# Out:
# The Power BI solution works by publishing the finalized dashboard to the Power BI service. It is then shared with relevant hospital staff, department heads, and administrators, or embedded into a report or website for access by external stakeholders. Appropriate access permissions are set to ensure that only authorized users can view and interact with the data. Users can explore the data independently and uncover hidden patterns or anomalies through interactive elements such as slicers, drill-throughs to more detailed reports, and tooltips providing contextual information. Effective design also considers performance optimization to ensure dashboards load quickly and respond efficiently.

# %%
response = rag_chain.invoke(
    "How does your dashboard improve decision-making?"
)
print(response)
# Out:
# Based on the context, the dashboard improves decision-making by being intuitive, user-friendly, reliable, and by providing actionable data.

# %%
response = rag_chain.invoke(
    "What is your project about?"
)
print(response)
# Out:
# Based on the context, the project is about creating a dashboard to enhance user engagement and exploration, facilitating deeper insights and understanding of energy consumption dynamics. This dashboard empowers stakeholders to interactively manipulate and explore data, participate in the analysis process, and ultimately manage and optimize energy resources and costs across diverse buildings and regions.
